# %% [markdown]
# # Business Intelligence & Big Data: Lab 4 Tasks
#
# #### Student ID: Put your Student ID here
# #### Student Name: Put your name here

# %% [markdown]
# #### Lab Task 1
# 1.	Write code to import numpy and pandas.

# %%
#Your code here
#Task 1
import numpy as np
import pandas as pd
pd.set_option("display.precision", 2)
print ("\nTask 01:\n")
print ("numpy and pandas successfully import\n")
# Out:
# Task 01:
#
# numpy and pandas successfully import

# %% [markdown]
# #### Lab Task 2
# 2. Write code to import the dataset as a pandas dataframe.

# %%
#Your code here
#task 02
df=pd.read_csv('C:\\Users\\waqar\\Desktop\\telecom_churn.csv')
print ("\nTask 02:\n")
print ("Dataset successfully import\n")
# Out:
# Task 02:
#
# Dataset successfully import

# %% [markdown]
# #### Lab Task 3
# 3.	Write code to display first 10 rows of dataframe as head.

# %%
#Your code here
print ("\nTask 03:\n")
print ("first ten rows are:\n")
print(df.head(10))
# Out:
# Task 03:
#
# first ten rows are:
#
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# ...

# %% [markdown]
# #### Lab Task 4
# 4.	Write code to display whole dataframe with maximun 200 rows to be displayed in the output table.

# %%
#Your code here
print(df.iloc[0:200,0:len(df.columns)])
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      KS             128        415                 No             Yes
# 1      OH             107        415                 No             Yes
# 2      NJ             137        415                 No              No
# 3      OH              84        408                Yes              No
# 4      OK              75        415                Yes              No
# 5      AL             118        510                Yes              No
# 6      MA             121        510                 No             Yes
# 7      MO             147        415                Yes              No
# 8      LA             117        408                 No              No
# 9      WV             141        415                Yes             Yes
# 10     IN              65        415                 No              No
# 11     RI              74        415                 No              No
# ...

# %% [markdown]
# #### Lab Task 5
# 5.	Write code to display state, account length, and today day minutes for first 500 clients.

# %%
#Your code here
#Task 05
print ("\nTask 05:\n")
print (df.loc[0:499, ["State", "Account length","Total day minutes"]])
# Out:
# Task 05:
#
#     State  Account length  Total day minutes
# 0      KS             128              265.1
# 1      OH             107              161.6
# 2      NJ             137              243.4
# 3      OH              84              299.4
# 4      OK              75              166.7
# ..    ...             ...                ...
# 495    FL             161              156.1
# 496    CA              93              178.7
# 497    AL             144              177.5
# 498    ME              75              211.3
# 499    WV              95              175.2
#
# [500 rows x 3 columns]

# %% [markdown]
# #### Lab Task 6
# 6.	Write code to convert the data type of “Total eve calls” from int64 to float64.

# %%
#Your code here
print (df['Total eve calls'].astype(np.float64))
# Out:
# 0        99.0
# 1       103.0
# 2       110.0
# 3        88.0
# 4       122.0
#         ...
# 3328    126.0
# 3329     55.0
# 3330     58.0
# 3331     84.0
# 3332     82.0
# Name: Total eve calls, Length: 3333, dtype: float64

# %% [markdown]
# #### Lab Task 7
# 7.	Write code to display value counts for state feature.

# %%
#Your code here
df['State'].value_counts()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# ID     73
# VT     73
# MI     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# MT     68
# NJ     68
# NC     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# MO     63
# FL     63
# ND     62
# NM     62
# ME     62
# OK     61
# DE     61
# NE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# TN     53
# HI     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64

# %% [markdown]
# #### Lab Task 8
# 8.	Write code to display fractional value counts for state feature.

# %%
#Your code here
print (df['State'].value_counts(normalize=True))
# Out:
# WV    0.03
# MN    0.03
# NY    0.02
# AL    0.02
# WI    0.02
# OH    0.02
# OR    0.02
# WY    0.02
# VA    0.02
# CT    0.02
# ID    0.02
# VT    0.02
# MI    0.02
# TX    0.02
# UT    0.02
# IN    0.02
# MD    0.02
# KS    0.02
# MT    0.02
# NJ    0.02
# NC    0.02
# CO    0.02
# NV    0.02
# WA    0.02
# RI    0.02
# MA    0.02
# MS    0.02
# AZ    0.02
# MO    0.02
# FL    0.02
# ND    0.02
# NM    0.02
# ME    0.02
# OK    0.02
# DE    0.02
# NE    0.02
# SC    0.02
# SD    0.02
# KY    0.02
# IL    0.02
# NH    0.02
# AR    0.02
# GA    0.02
# DC    0.02
# TN    0.02
# HI    0.02
# AK    0.02
# LA    0.02
# PA    0.01
# IA    0.01
# CA    0.01
# Name: State, dtype: float64

# %% [markdown]
# #### Lab Task 9
# 9.	Write code to display a histogram for “Total eve calls”.

# %%
#Your code here
#task 09
df['Total eve calls'].hist()

# %% [markdown]
# #### Lab Task 10
# 10.	Write code to display a histogram for “Total day charge”.

# %%
#Your code here
#task 10
df['Total day charge'].hist()
